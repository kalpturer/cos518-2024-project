# %%
import matplotlib.pyplot as plt
import numpy as np

from aquarel import load_theme

theme = load_theme("scientific").set_font(size=8)
theme.apply()
current_color_cycle = plt.rcParams['axes.prop_cycle'].by_key()['color']
colors3 = current_color_cycle[:3]
colors5 = current_color_cycle[:5]

# %%
conflict_rate = "0.00"
sleep = "25"

def plot_histogram(input_files):
    datas = []
    filtered_datas = []
    locations = ['California', 'Ohio', 'North Virginia']
    medians = []
    count = 0
    for i in range(len(input_files)):
        input_file = input_files[i]
        data = []
        with open(input_file, 'r') as f:
            lines = f.readlines()
    
    
        for line in lines[2:]:
            if line[0] == 'R':
                print("Warning: timedout requests in data")
            else:
                data.append(int(line.strip()[:-2]))
                count += 1

        # remove outliers
        threshold = np.percentile(data, 99)
        data = np.array(data)
        filtered_data = data[data <= threshold]
        
        datas.append(data)
        filtered_datas.append(filtered_data)

        print("Median latency in", locations[i], ":", np.median(data))
        medians.append(np.median(data))
        print("outliers within one percent:", data[data > threshold])
    print("Throughput: ", count / 30)

    plt.hist(filtered_datas[0], bins=100)
    plt.hist(filtered_datas[1], bins=100)
    plt.hist(filtered_datas[2], bins=100)
    plt.xlabel('Latency (ms)')
    plt.ylabel('Frequency')
    plt.title(f'Latency Distribution 3 Replicas (conflict rate {conflict_rate}, latency within 99th percentile)')
    plt.grid(True)
    plt.legend(locations)
    theme.apply_transforms()
    plt.savefig(f'3replicas_sleep{sleep}_conflict{conflict_rate}_dist_domestic.png', bbox_inches='tight')
    plt.show()

    #####################################################################################
    plt.bar(locations, medians, color=colors3)
    plt.xlabel('Locations')
    plt.ylabel('Median latency (ms)')
    plt.title(f'Median latency with 3 Replicas (conflict rate {conflict_rate})')
    theme.apply_transforms()
    plt.savefig(f'3replicas_sleep{sleep}_conflict{conflict_rate}_loc_domestic.png', bbox_inches='tight')
    plt.show()

input_files = [f'./data/domestic/results_3_replicas_california_ohio_virginia/results_{conflict_rate}conflict/exp3_california_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_3_replicas_california_ohio_virginia/results_{conflict_rate}conflict/exp3_ohio_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_3_replicas_california_ohio_virginia/results_{conflict_rate}conflict/exp3_virginia_sleep{{{sleep}}}_time{{30}}.txt']
plot_histogram(input_files)
# Out:
# Median latency in California : 156.0
# outliers within one percent: [285 270 301 277 288 277 268 278 269 273 264 290]
# Median latency in Ohio : 52.0
# outliers within one percent: [189 187 213 188 200 190 215 198 221 246 192 228]
# Median latency in North Virginia : 197.0
# outliers within one percent: [347 333 358 350 357 383 333 338 331 357 383 364]
# Throughput:  119.56666666666666

# %%
conflict_rate = "0.02"
sleep = "25"

def plot_histogram(input_files):
    datas = []
    filtered_datas = []
    locations = ['California', 'Ohio', 'North Virginia']
    medians = []
    count = 0
    for i in range(len(input_files)):
        input_file = input_files[i]
        data = []
        with open(input_file, 'r') as f:
            lines = f.readlines()
    
    
        for line in lines[2:]:
            if line[0] == 'R':
                print("Warning: timedout requests in data")
            else:
                data.append(int(line.strip()[:-2]))
                count += 1

        # remove outliers
        threshold = np.percentile(data, 99)
        data = np.array(data)
        filtered_data = data[data <= threshold]
        
        datas.append(data)
        filtered_datas.append(filtered_data)

        print("Median latency in", locations[i], ":", np.median(data))
        medians.append(np.median(data))
        print("outliers within one percent:", data[data > threshold])
    print("Throughput: ", count / 30)

    plt.hist(filtered_datas[0], bins=100)
    plt.hist(filtered_datas[1], bins=100)
    plt.hist(filtered_datas[2], bins=100)
    plt.xlabel('Latency (ms)')
    plt.ylabel('Frequency')
    plt.title(f'Latency Distribution 3 Replicas (conflict rate {conflict_rate}, latency within 99th percentile)')
    plt.grid(True)
    plt.legend(locations)
    theme.apply_transforms()
    plt.savefig(f'3replicas_sleep{sleep}_conflict{conflict_rate}_dist_domestic.png', bbox_inches='tight')
    plt.show()

    #####################################################################################
    plt.bar(locations, medians, color=colors3)
    plt.xlabel('Locations')
    plt.ylabel('Median latency (ms)')
    plt.title(f'Median latency with 3 Replicas (conflict rate {conflict_rate})')
    theme.apply_transforms()
    plt.savefig(f'3replicas_sleep{sleep}_conflict{conflict_rate}_loc_domestic.png', bbox_inches='tight')
    plt.show()

input_files = [f'./data/domestic/results_3_replicas_california_ohio_virginia/results_{conflict_rate}conflict/exp3_california_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_3_replicas_california_ohio_virginia/results_{conflict_rate}conflict/exp3_ohio_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_3_replicas_california_ohio_virginia/results_{conflict_rate}conflict/exp3_virginia_sleep{{{sleep}}}_time{{30}}.txt']
plot_histogram(input_files)
# Out:
# Median latency in California : 161.5
# outliers within one percent: [391 407 388 444 420 395 391 467 412 413 454]
# Median latency in Ohio : 57.0
# outliers within one percent: [251 252 264 269 244 290 265 251 276 282 257]
# Median latency in North Virginia : 200.0
# outliers within one percent: [363 402 377 429 411 387 362 375 384 410 361 387]
# Throughput:  119.6

# %%
conflict_rate = "1.00"
sleep = "100"

def plot_histogram(input_files):
    datas = []
    filtered_datas = []
    locations = ['California', 'Ohio', 'North Virginia']
    medians = []
    count = 0
    for i in range(len(input_files)):
        input_file = input_files[i]
        data = []
        with open(input_file, 'r') as f:
            lines = f.readlines()
    
    
        for line in lines[2:]:
            if line[0] == 'R':
                print("Warning: timedout requests in data")
            else:
                data.append(int(line.strip()[:-2]))
                count += 1

        # remove outliers
        threshold = np.percentile(data, 99)
        data = np.array(data)
        filtered_data = data[data <= threshold]
        
        datas.append(data)
        filtered_datas.append(filtered_data)

        print("Median latency in", locations[i], ":", np.median(data))
        medians.append(np.median(data))
        print("outliers within one percent:", data[data > threshold])
    print("Throughput: ", count / 30)

    plt.hist(filtered_datas[0], bins=100)
    plt.hist(filtered_datas[1])#, bins=100)
    plt.hist(filtered_datas[2])#, bins=100)
    plt.xlabel('Latency (ms)')
    plt.ylabel('Frequency')
    plt.title(f'Latency Distribution 3 Replicas (conflict rate {conflict_rate}, latency within 99th percentile)')
    plt.grid(True)
    plt.legend(locations)
    theme.apply_transforms()
    plt.savefig(f'3replicas_sleep{sleep}_conflict{conflict_rate}_dist_domestic.png', bbox_inches='tight')
    plt.show()

    #####################################################################################
    plt.bar(locations, medians, color=colors3)
    plt.xlabel('Locations')
    plt.ylabel('Median latency (ms)')
    plt.title(f'Median latency with 3 Replicas (conflict rate {conflict_rate})')
    theme.apply_transforms()
    plt.savefig(f'3replicas_sleep{sleep}_conflict{conflict_rate}_loc_domestic.png', bbox_inches='tight')
    plt.show()

input_files = [f'./data/domestic/results_3_replicas_california_ohio_virginia/results_{conflict_rate}conflict/exp3_california_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_3_replicas_california_ohio_virginia/results_{conflict_rate}conflict/exp3_ohio_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_3_replicas_california_ohio_virginia/results_{conflict_rate}conflict/exp3_virginia_sleep{{{sleep}}}_time{{30}}.txt']
plot_histogram(input_files)
# Out:
# Median latency in California : 180.5
# outliers within one percent: [2602 2702 2528]
# Median latency in Ohio : 65.5
# outliers within one percent: [434 513 542]
# Median latency in North Virginia : 215.0
# outliers within one percent: [429 611 607]
# Throughput:  30.0

# %%
conflict_rate = "0.00"
sleep = "40"

def plot_histogram(input_files):
    datas = []
    filtered_datas = []
    locations = ['California', 'Ohio', 'North Virginia', 'Oregon', 'Canada']
    medians = []
    count = 0

    for i in range(len(input_files)):
        input_file = input_files[i]
        data = []
        with open(input_file, 'r') as f:
            lines = f.readlines()
    
    
        for line in lines[2:]:
            if line[0] == 'R':
                print("Warning: timedout requests in data")
            else:
                data.append(int(line.strip()[:-2]))
                count += 1

        # remove outliers
        threshold = np.percentile(data, 99)
        data = np.array(data)
        filtered_data = data[data <= threshold]
        
        datas.append(data)
        filtered_datas.append(filtered_data)

        print("Median latency in", locations[i], ":", np.median(data))
        medians.append(np.median(data))
        print("outliers within one percent:", data[data > threshold])
    print("Throughput: ", count / 30)


    plt.hist(filtered_datas[0], bins=100)
    plt.hist(filtered_datas[1], bins=100)
    plt.hist(filtered_datas[2], bins=100)
    plt.hist(filtered_datas[3], bins=200)
    plt.hist(filtered_datas[4], bins=100)
    plt.xlabel('Latency (ms)')
    plt.ylabel('Frequency')
    plt.title(f'Latency Distribution 3 Replicas (conflict rate {conflict_rate}, latency within 99th percentile)')
    plt.grid(True)
    plt.legend(locations)
    theme.apply_transforms()
    plt.savefig(f'5replicas_sleep{sleep}_conflict{conflict_rate}_dist_domestic.png', bbox_inches='tight')
    plt.show()

    #####################################################################################
    plt.bar(locations, medians, color=colors5)
    plt.xlabel('Locations')
    plt.ylabel('Median latency (ms)')
    plt.title(f'Median latency with 3 Replicas (conflict rate {conflict_rate})')
    theme.apply_transforms()
    plt.savefig(f'5replicas_sleep{sleep}_conflict{conflict_rate}_loc_domestic.png', bbox_inches='tight')
    plt.show()

input_files = [f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_california_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_ohio_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_virginia_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_oregon_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_canada_sleep{{{sleep}}}_time{{30}}.txt']
plot_histogram(input_files)
# Out:
# Median latency in California : 154.0
# outliers within one percent: [352 361 385 426 424 384 465 354]
# Median latency in Ohio : 55.0
# outliers within one percent: [319 314 317 307 314 321 375 365]
# Median latency in North Virginia : 189.0
# outliers within one percent: [574 537 497 617 674 634 797 758]
# Median latency in Oregon : 182.0
# outliers within one percent: [1015 1018  978 1058 1106  978 1018 1058]
# Median latency in Canada : 232.0
# outliers within one percent: [547 522 539 567 527 596 558 518]
# Throughput:  124.76666666666667

# %%
conflict_rate = "0.02"
sleep = "40"

def plot_histogram(input_files):
    datas = []
    filtered_datas = []
    locations = ['California', 'Ohio', 'North Virginia', 'Oregon', 'Canada']
    medians = []
    count = 0

    for i in range(len(input_files)):
        input_file = input_files[i]
        data = []
        with open(input_file, 'r') as f:
            lines = f.readlines()
    
    
        for line in lines[2:]:
            if line[0] == 'R':
                print("Warning: timedout requests in data")
            else:
                data.append(int(line.strip()[:-2]))
                count += 1

        # remove outliers
        threshold = np.percentile(data, 99)
        data = np.array(data)
        filtered_data = data[data <= threshold]
        
        datas.append(data)
        filtered_datas.append(filtered_data)

        print("Median latency in", locations[i], ":", np.median(data))
        medians.append(np.median(data))
        print("outliers within one percent:", data[data > threshold])
    print("Throughput: ", count / 30)


    plt.hist(filtered_datas[0], bins=100)
    plt.hist(filtered_datas[1], bins=100)
    plt.hist(filtered_datas[2], bins=100)
    plt.hist(filtered_datas[3], bins=150)
    plt.hist(filtered_datas[4], bins=100)
    plt.xlabel('Latency (ms)')
    plt.ylabel('Frequency')
    plt.title(f'Latency Distribution 3 Replicas (conflict rate {conflict_rate}, latency within 99th percentile)')
    plt.grid(True)
    plt.legend(locations)
    theme.apply_transforms()
    plt.savefig(f'5replicas_sleep{sleep}_conflict{conflict_rate}_dist_domestic.png', bbox_inches='tight')
    plt.show()

    #####################################################################################
    plt.bar(locations, medians, color=colors5)
    plt.xlabel('Locations')
    plt.ylabel('Median latency (ms)')
    plt.title(f'Median latency with 3 Replicas (conflict rate {conflict_rate})')
    theme.apply_transforms()
    plt.savefig(f'5replicas_sleep{sleep}_conflict{conflict_rate}_loc_domestic.png', bbox_inches='tight')
    plt.show()

input_files = [f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_california_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_ohio_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_virginia_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_oregon_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_canada_sleep{{{sleep}}}_time{{30}}.txt']
plot_histogram(input_files)
# Out:
# Median latency in California : 157.0
# outliers within one percent: [499 589 509 550 584 544 504 508]
# Median latency in Ohio : 51.0
# outliers within one percent: [347 355 336 376 375 389 429 469]
# Median latency in North Virginia : 183.0
# outliers within one percent: [350 373 337 364 354 339 338 379]
# Median latency in Oregon : 181.0
# outliers within one percent: [1443 1483 1523 1403 1402 1482 1442]
# Median latency in Canada : 232.0
# outliers within one percent: [799 839 873 914 994 955 956 916]
# Throughput:  124.83333333333333

# %%
conflict_rate = "1.00"
sleep = "150"

def plot_histogram(input_files):
    datas = []
    filtered_datas = []
    locations = ['California', 'Ohio', 'North Virginia', 'Oregon', 'Canada']
    medians = []
    count = 0

    for i in range(len(input_files)):
        input_file = input_files[i]
        data = []
        with open(input_file, 'r') as f:
            lines = f.readlines()
    
    
        for line in lines[2:]:
            if line[0] == 'R':
                print("Warning: timedout requests in data")
            else:
                data.append(int(line.strip()[:-2]))
                count += 1

        # remove outliers
        threshold = np.percentile(data, 99)
        data = np.array(data)
        filtered_data = data[data <= threshold]
        
        datas.append(data)
        filtered_datas.append(filtered_data)

        print("Median latency in", locations[i], ":", np.median(data))
        medians.append(np.median(data))
        print("outliers within one percent:", data[data > threshold])
    print("Throughput: ", count / 30)


    plt.hist(filtered_datas[0], bins=100)
    plt.hist(filtered_datas[1], bins=100)
    plt.hist(filtered_datas[2], bins=100)
    plt.hist(filtered_datas[3], bins=100)
    plt.hist(filtered_datas[4], bins=100)
    plt.xlabel('Latency (ms)')
    plt.ylabel('Frequency')
    plt.title(f'Latency Distribution 3 Replicas (conflict rate {conflict_rate}, latency within 99th percentile)')
    plt.grid(True)
    plt.legend(locations)
    theme.apply_transforms()
    plt.savefig(f'5replicas_sleep{sleep}_conflict{conflict_rate}_dist_domestic.png', bbox_inches='tight')
    plt.show()

    #####################################################################################
    plt.bar(locations, medians, color=colors5)
    plt.xlabel('Locations')
    plt.ylabel('Median latency (ms)')
    plt.title(f'Median latency with 3 Replicas (conflict rate {conflict_rate})')
    theme.apply_transforms()
    plt.savefig(f'5replicas_sleep{sleep}_conflict{conflict_rate}_loc_domestic.png', bbox_inches='tight')
    plt.show()

input_files = [f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_california_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_ohio_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_virginia_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_oregon_sleep{{{sleep}}}_time{{30}}.txt',
               f'./data/domestic/results_5_replicas_california_ohio_virginia_oregon_canada/results_{conflict_rate}conflict/exp3_canada_sleep{{{sleep}}}_time{{30}}.txt']
plot_histogram(input_files)
# Out:
# Median latency in California : 253.0
# outliers within one percent: [1275 1356]
# Median latency in Ohio : 168.5
# outliers within one percent: [1367 1218]
# Median latency in North Virginia : 327.5
# outliers within one percent: [1342 1520]
# Median latency in Oregon : 328.0
# outliers within one percent: [1363 1514]
# Median latency in Canada : 339.0
# outliers within one percent: [1300 1402]
# Throughput:  33.333333333333336

# %%
locations = ['3 replicas 0%', '3 replicas 2%', '3 replicas 100%', '5 replicas 0%', '5 replicas 2%', '5 replicas 100%']
throughput = [119.5, 119.6, 30.0, 124.8, 124.8, 33.0]
plt.barh(locations, throughput)
plt.ylabel('')
plt.xlabel('Throughput (reqs/sec)')
plt.title(f'Average throughput (Domestic)')
theme.apply_transforms()
plt.savefig(f'all_conflict_throughput_dist_domestic.png', bbox_inches='tight')
plt.show()
